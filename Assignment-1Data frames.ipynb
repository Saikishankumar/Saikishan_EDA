# %% [markdown]
# **Assignment-1**

# %% [markdown]
# **Basic data frame operations**

# %%
import pandas as pd 
import numpy as np   
import matplotlib.pyplot as plt  
import seaborn as sns

# %%
path=r"C:\Users\saiki\data science\datasets\winequality_red.xlsx"

# %%
pd.read_excel(path)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               NaN               NaN          NaN             NaN        NaN
# 1               7.4             0.700         0.00             1.9      0.076
# 2               NaN               NaN          NaN             NaN        NaN
# 3               7.8             0.880         0.00             2.6      0.098
# 4               NaN               NaN          NaN             NaN        NaN
# ...             ...               ...          ...             ...        ...
# 3193            6.3             0.510         0.13             2.3      0.076
# 3194            NaN               NaN          NaN             NaN        NaN
# 3195            5.9             0.645         0.12             2.0      0.075
# 3196            NaN               NaN          NaN             NaN        NaN
# 3197            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
name=['Ramesh','Suresh','Satish','kishan','suman','nithin','sandesh','rohith']
age=[30,35,40,30,40,39,36,69,71]
name,age
# Out:
# (['Ramesh',
#   'Suresh',
#   'Satish',
#   'kishan',
#   'suman',
#   'nithin',
#   'sandesh',
#   'rohith'],
#  [30, 35, 40, 30, 40, 39, 36, 69, 71])

# %% [markdown]
# $step-1$

# %% [markdown]
# $create$ $dataframe$

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# $step-2$

# %% [markdown]
# $creating$ $dataframes$ $from$ $given$ $list$

# %%
pd.DataFrame(zip(name,age))
# Out:
#          0   1
# 0   Ramesh  30
# 1   Suresh  35
# 2   Satish  40
# 3   kishan  30
# 4    suman  40
# 5   nithin  39
# 6  sandesh  36
# 7   rohith  69

# %% [markdown]
# $step-3$

# %% [markdown]
# $provide$ $columns$

# %%
pd.DataFrame(zip(name,age),columns=['name','age'])
# Out:
#       name  age
# 0   Ramesh   30
# 1   Suresh   35
# 2   Satish   40
# 3   kishan   30
# 4    suman   40
# 5   nithin   39
# 6  sandesh   36
# 7   rohith   69

# %% [markdown]
# $step-4$

# %% [markdown]
# $Provide$ $index$

# %%
pd.DataFrame(zip(name,age),columns=['name','age'],index=['A','B','C','D','E','F','G','H'])
# Out:
#       name  age
# A   Ramesh   30
# B   Suresh   35
# C   Satish   40
# D   kishan   30
# E    suman   40
# F   nithin   39
# G  sandesh   36
# H   rohith   69

# %% [markdown]
# $step-5$

# %% [markdown]
# $Add$ $new$ $column$

# %%
df=pd.DataFrame(zip(name,age),columns=['name','age'],index=['A','B','C','D','E','F','G','H'])
city_names=["Hyd","Hyd","Hyd","Banglore","USA","Delhi","Mumbai","Pune"]
relations=['not friend','not friend','not friend','friend','school friend','inter friend','inter friend','inter friend']
df["city"]=city_names
df["Relation"]=relations
df
# Out:
#       name  age      city       Relation
# A   Ramesh   30       Hyd     not friend
# B   Suresh   35       Hyd     not friend
# C   Satish   40       Hyd     not friend
# D   kishan   30  Banglore         friend
# E    suman   40       USA  school friend
# F   nithin   39     Delhi   inter friend
# G  sandesh   36    Mumbai   inter friend
# H   rohith   69      Pune   inter friend

# %% [markdown]
# $step-6$

# %% [markdown]
# $update$ $the$ $exsisting$ $column$

# %%
df["name"]=["Ram","Suri","Sati","Kit","Biswas","Goka","Sandy","Rohit"]
df
# Out:
#      name  age      city       Relation
# A     Ram   30       Hyd     not friend
# B    Suri   35       Hyd     not friend
# C    Sati   40       Hyd     not friend
# D     Kit   30  Banglore         friend
# E  Biswas   40       USA  school friend
# F    Goka   39     Delhi   inter friend
# G   Sandy   36    Mumbai   inter friend
# H   Rohit   69      Pune   inter friend

# %% [markdown]
# $step-7$

# %% [markdown]
# $drop$ $the$ $column$

# %%
df.drop("Relation",axis=1,inplace=True)
df
# Out:
#      name  age      city
# A     Ram   30       Hyd
# B    Suri   35       Hyd
# C    Sati   40       Hyd
# D     Kit   30  Banglore
# E  Biswas   40       USA
# F    Goka   39     Delhi
# G   Sandy   36    Mumbai
# H   Rohit   69      Pune

# %% [markdown]
# $step-8$

# %% [markdown]
# $drop$ $the$ $row$

# %%
df.drop("H",axis=0,inplace=True)
df
# Out:
#      name  age      city
# A     Ram   30       Hyd
# B    Suri   35       Hyd
# C    Sati   40       Hyd
# D     Kit   30  Banglore
# E  Biswas   40       USA
# F    Goka   39     Delhi
# G   Sandy   36    Mumbai

# %% [markdown]
# $step-9$

# %% [markdown]
# $save$ $the$ $dataframe$

# %%
df.to_excel("output.xlsx")

# %%
pd.read_excel("output.xlsx")
# Out:
#   Unnamed: 0    name  age      city
# 0          A     Ram   30       Hyd
# 1          B    Suri   35       Hyd
# 2          C    Sati   40       Hyd
# 3          D     Kit   30  Banglore
# 4          E  Biswas   40       USA
# 5          F    Goka   39     Delhi
# 6          G   Sandy   36    Mumbai

# %% [markdown]
# $step-10$

# %% [markdown]
# $remove$ $the$ $index$

# %%
df.to_excel("output.xlsx",index=False)
pd.read_excel("output.xlsx")
# Out:
#      name  age      city
# 0     Ram   30       Hyd
# 1    Suri   35       Hyd
# 2    Sati   40       Hyd
# 3     Kit   30  Banglore
# 4  Biswas   40       USA
# 5    Goka   39     Delhi
# 6   Sandy   36    Mumbai

# %% [markdown]
# # Create dataframes using dictionary

# %%
d1={"NAME":['Ramesh','Suresh','Satish','kishan','suman','nithin','sandesh','rohith','sandy'],
"AGE":[30,35,40,30,40,39,36,69,71]}
pd.DataFrame(d1)
# Out:
#       NAME  AGE
# 0   Ramesh   30
# 1   Suresh   35
# 2   Satish   40
# 3   kishan   30
# 4    suman   40
# 5   nithin   39
# 6  sandesh   36
# 7   rohith   69
# 8    sandy   71

# %% [markdown]
# $step-4$

# %%
d1={"NAME":['Ramesh','Suresh','Satish','kishan','suman','nithin','sandesh','rohith','sandy'],
"AGE":[30,35,40,30,40,39,36,69,71]}
pd.DataFrame(d1,index=['A','B','C','D','E','F','G','H','I'])
# Out:
#       NAME  AGE
# A   Ramesh   30
# B   Suresh   35
# C   Satish   40
# D   kishan   30
# E    suman   40
# F   nithin   39
# G  sandesh   36
# H   rohith   69
# I    sandy   71

# %% [markdown]
# $step-5$

# %%
df1=pd.DataFrame(d1,index=['A','B','C','D','E','F','G','H','I'])
city_names=["Hyd","Hyd","Hyd","Banglore","USA","Delhi","Mumbai","pondicherry","Pune"]
df1["city"]=city_names
df1
# Out:
#       NAME  AGE         city
# A   Ramesh   30          Hyd
# B   Suresh   35          Hyd
# C   Satish   40          Hyd
# D   kishan   30     Banglore
# E    suman   40          USA
# F   nithin   39        Delhi
# G  sandesh   36       Mumbai
# H   rohith   69  pondicherry
# I    sandy   71         Pune

# %% [markdown]
# $step-6$

# %%
df1["city"]=["hyd","hyd","hyd","Bgl","USA","Delhi","Mum","pond","Pune"]
df1
# Out:
#       NAME  AGE   city
# A   Ramesh   30    hyd
# B   Suresh   35    hyd
# C   Satish   40    hyd
# D   kishan   30    Bgl
# E    suman   40    USA
# F   nithin   39  Delhi
# G  sandesh   36    Mum
# H   rohith   69   pond
# I    sandy   71   Pune

# %% [markdown]
# $step-7$

# %%
df1.drop("AGE",axis=1,inplace=True)
df1
# Out:
#       NAME   city
# A   Ramesh    hyd
# B   Suresh    hyd
# C   Satish    hyd
# D   kishan    Bgl
# E    suman    USA
# F   nithin  Delhi
# G  sandesh    Mum
# H   rohith   pond
# I    sandy   Pune

# %% [markdown]
# $step-8$

# %%
df1.drop("I",axis=0,inplace=True)
df1
# Out:
#       NAME   city
# A   Ramesh    hyd
# B   Suresh    hyd
# C   Satish    hyd
# D   kishan    Bgl
# E    suman    USA
# F   nithin  Delhi
# G  sandesh    Mum
# H   rohith   pond

# %% [markdown]
# $step-9$

# %%
df1.to_excel("output.xlsx")

# %%
pd.read_excel("output.xlsx")
# Out:
#   Unnamed: 0     NAME   city
# 0          A   Ramesh    hyd
# 1          B   Suresh    hyd
# 2          C   Satish    hyd
# 3          D   kishan    Bgl
# 4          E    suman    USA
# 5          F   nithin  Delhi
# 6          G  sandesh    Mum
# 7          H   rohith   pond

# %% [markdown]
# $step-10$

# %%
df1.to_excel("output.xlsx",index=False)

# %%
pd.read_excel("output.xlsx")
# Out:
#       NAME   city
# 0   Ramesh    hyd
# 1   Suresh    hyd
# 2   Satish    hyd
# 3   kishan    Bgl
# 4    suman    USA
# 5   nithin  Delhi
# 6  sandesh    Mum
# 7   rohith   pond
