# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path=r"C:\Users\saiki\data science\datasets\Hackathon\train_ctrUa4K.csv"
loan_df=pd.read_csv(path)
loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_df.head(4)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y

# %%
loan_df.tail(5)
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
loan_df.shape
# Out:
# (614, 13)

# %%
loan_df.size
# Out:
# 7982

# %%
loan_df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
type(loan_df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(loan_df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
loan_df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
type(loan_df.dtypes)
# Out:
# pandas.core.series.Series

# %%
dict(loan_df.dtypes)
# Out:
# {'Loan_ID': dtype('O'),
#  'Gender': dtype('O'),
#  'Married': dtype('O'),
#  'Dependents': dtype('O'),
#  'Education': dtype('O'),
#  'Self_Employed': dtype('O'),
#  'ApplicantIncome': dtype('int64'),
#  'CoapplicantIncome': dtype('float64'),
#  'LoanAmount': dtype('float64'),
#  'Loan_Amount_Term': dtype('float64'),
#  'Credit_History': dtype('float64'),
#  'Property_Area': dtype('O'),
#  'Loan_Status': dtype('O')}

# %%
d1=dict(loan_df.dtypes)
for i in d1:
    if d1[i]=='object':
        print(i)
cat=[i for i in d1 if d1[i]=='object']
num=[i for i in d1 if d1[i]!='object']
print(cat)
print(num)
# Out:
# Loan_ID
# Gender
# Married
# Dependents
# Education
# Self_Employed
# Property_Area
# Loan_Status
# ['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Property_Area', 'Loan_Status']
# ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History']

# %%
loan_df.select_dtypes(include='object').columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
loan_df.select_dtypes(include='object')
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#     Property_Area Loan_Status
# 0           Urban           Y
# 1           Rural           N
# 2           Urban           Y
# ...

# %%
loan_df.select_dtypes(exclude='object')
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History
# 0               1.0
# 1               1.0
# 2               1.0
# 3               1.0
# ...

# %%
loan_df.select_dtypes(exclude='object').columns
# Out:
# Index(['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History'],
#       dtype='object')

# %%
loan_df.isnull()
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      False   False    False       False      False          False
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 609    False   False    False       False      False          False
# 610    False   False    False       False      False          False
# 611    False   False    False       False      False          False
# 612    False   False    False       False      False          False
# 613    False   False    False       False      False          False
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              False              False        True             False
# ...

# %%
loan_df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
loan_df.drop_duplicates()
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
loan_df.take([2,3,4])
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
loan_df.take([2,3,4],axis=1)
# Out:
#     Married Dependents     Education
# 0        No          0      Graduate
# 1       Yes          1      Graduate
# 2       Yes          0      Graduate
# 3       Yes          0  Not Graduate
# 4        No          0      Graduate
# ..      ...        ...           ...
# 609      No          0      Graduate
# 610     Yes         3+      Graduate
# 611     Yes          1      Graduate
# 612     Yes          2      Graduate
# 613      No          0      Graduate
#
# [614 rows x 3 columns]

# %%
loan_df.iloc[5:10]
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes         3+      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 5             5417             4196.0       267.0             360.0
# 6             2333             1516.0        95.0             360.0
# 7             3036             2504.0       158.0             360.0
# 8             4006             1526.0       168.0             360.0
# 9            12841            10968.0       349.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 5             1.0         Urban           Y
# 6             1.0         Urban           Y
# ...

# %%
loan_df.iloc[5:10,2:5]
# Out:
#   Married Dependents     Education
# 5     Yes          2      Graduate
# 6     Yes          0  Not Graduate
# 7     Yes         3+      Graduate
# 8     Yes          2      Graduate
# 9     Yes          1      Graduate

# %%
loan_df.iloc[[100,200,300],[8]]
# Out:
#      LoanAmount
# 100       133.0
# 200        90.0
# 300        93.0

# %%
loan_df.loc[[610,280,300],['Married']]
# Out:
#     Married
# 610     Yes
# 280      No
# 300     Yes

# %%
col=['Married']
loan_df[col]
# Out:
#     Married
# 0        No
# 1       Yes
# 2       Yes
# 3       Yes
# 4        No
# ..      ...
# 609      No
# 610     Yes
# 611     Yes
# 612     Yes
# 613      No
#
# [614 rows x 1 columns]

# %%
loan_df['Married'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
set(loan_df['Married'].values)
# Out:
# {'No', 'Yes', nan}

# %%
loan_df['Married'].nunique()
# Out:
# 2

# %%
mar=loan_df['Married']=='Yes'  # True and false
loan_df[mar]
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 1    LP001003   Male     Yes          1      Graduate            No
# 2    LP001005   Male     Yes          0      Graduate           Yes
# 3    LP001006   Male     Yes          0  Not Graduate            No
# 5    LP001011   Male     Yes          2      Graduate           Yes
# 6    LP001013   Male     Yes          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 607  LP002964   Male     Yes          2  Not Graduate            No
# 608  LP002974   Male     Yes          0      Graduate            No
# 610  LP002979   Male     Yes         3+      Graduate            No
# 611  LP002983   Male     Yes          1      Graduate            No
# 612  LP002984   Male     Yes          2      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1               4583             1508.0       128.0             360.0
# ...

# %%
edu=loan_df['Education']=='Graduate'  # True and false
loan_df[edu]
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 0    LP001002    Male      No          0  Graduate            No
# 1    LP001003    Male     Yes          1  Graduate            No
# 2    LP001005    Male     Yes          0  Graduate           Yes
# 4    LP001008    Male      No          0  Graduate            No
# 5    LP001011    Male     Yes          2  Graduate           Yes
# ..        ...     ...     ...        ...       ...           ...
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# ...

# %%
loan_df['Education'].nunique()
# Out:
# 2

# %%
unique_labels=loan_df['Education'].unique()
count=[]
for i in unique_labels:
    edu=loan_df['Education']==i  # True and false
    count.append(len(loan_df[edu]))
count
# Out:
# [480, 134]

# %%
unique_labels=loan_df['Education'].unique()
count=[]
for i in unique_labels:
    edu=loan_df['Education']==i  # True and false
    count.append(len(loan_df[edu]))
count
pd.DataFrame(zip(unique_labels,count),columns=['Education','count'])
# Out:
#       Education  count
# 0      Graduate    480
# 1  Not Graduate    134

# %%
Education_vc=loan_df['Education'].value_counts() # series
Education_vc
# Out:
# Education
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64

# %%
Education_vc=loan_df['Education'].value_counts()
l1=Education_vc.keys()
l2=Education_vc.values
Education_vc_df=pd.DataFrame(zip(l1,l2),columns=['Education','count'])
Education_vc_df
# Out:
#       Education  count
# 0      Graduate    480
# 1  Not Graduate    134

# %%
plt.bar('Education','count',data=Education_vc_df)
# Out:
# <BarContainer object of 2 artists>

# %%
plt.figure(figsize=(10,6))
plt.bar('Education','count',data=Education_vc_df)
plt.xlabel("Education")
plt.ylabel("count")
plt.title("Bar chart")
plt.show()

# %%
sns.countplot(data=loan_df,x='Education')
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
loan_df[['Education']]
# Out:
#         Education
# 0        Graduate
# 1        Graduate
# 2        Graduate
# 3    Not Graduate
# 4        Graduate
# ..            ...
# 609      Graduate
# 610      Graduate
# 611      Graduate
# 612      Graduate
# 613      Graduate
#
# [614 rows x 1 columns]

# %%
loan_df['Education']
# Out:
# 0          Graduate
# 1          Graduate
# 2          Graduate
# 3      Not Graduate
# 4          Graduate
#            ...
# 609        Graduate
# 610        Graduate
# 611        Graduate
# 612        Graduate
# 613        Graduate
# Name: Education, Length: 614, dtype: object

# %%
len(loan_df['Education'])
# Out:
# 614

# %%
loan_df['Education'].count()
# Out:
# 614

# %%
loan_df['ApplicantIncome'].mean()
# Out:
# 5403.459283387622

# %%
np.mean(loan_df['ApplicantIncome'])
# Out:
# 5403.459283387622

# %%
loan_df['ApplicantIncome'].median()
# Out:
# 3812.5

# %%
loan_df['ApplicantIncome'].max()
# Out:
# 81000

# %%
np.max(loan_df['ApplicantIncome'])
# Out:
# 81000

# %%
loan_df['ApplicantIncome'].min()
# Out:
# 150

# %%
np.min(loan_df['ApplicantIncome'])
# Out:
# 150

# %%
loan_df['ApplicantIncome'].std()
# Out:
# 6109.041673387174

# %%
loan_count=loan_df['Education'].count()
loan_mean=loan_df['ApplicantIncome'].mean()
loan_median=loan_df['ApplicantIncome'].median()
loan_max=loan_df['ApplicantIncome'].max()
loan_min=loan_df['ApplicantIncome'].min()
loan_std=loan_df['ApplicantIncome'].std()
l=[loan_count,loan_mean,loan_median,loan_max,loan_min,loan_std]
cols=['ApplicationIncome']
index=['count','mean','median','max','min','std']
pd.DataFrame(l,columns=cols,index=index)
# Out:
#         ApplicationIncome
# count          614.000000
# mean          5403.459283
# median        3812.500000
# max          81000.000000
# min            150.000000
# std           6109.041673

# %%
loan_df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
Q1=np.percentile(loan_df['ApplicantIncome'],25)
Q2=np.percentile(loan_df['ApplicantIncome'],50)
Q3=np.percentile(loan_df['ApplicantIncome'],75)
IQR=Q3-Q1
lb=Q1+(1.5*IQR)
ub=Q3+(1.5*IQR)
c1=loan_df['ApplicantIncome']<lb
c2=loan_df['ApplicantIncome']>ub
con=c1|c2
outlier_loan_df=loan_df[con]
outlier_loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 607  LP002964    Male     Yes          2  Not Graduate            No
# 608  LP002974    Male     Yes          0      Graduate            No
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
Q1=np.percentile(loan_df['ApplicantIncome'],25)
Q2=np.percentile(loan_df['ApplicantIncome'],50)
Q3=np.percentile(loan_df['ApplicantIncome'],75)
IQR=Q3-Q1
lb=Q1+(1.5*IQR)
ub=Q3+(1.5*IQR)
c1=loan_df['ApplicantIncome']>lb
c2=loan_df['ApplicantIncome']<ub
con=c1&c2
nonoutlier_loan_df=loan_df[con]
nonoutlier_loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 20   LP001043    Male     Yes          0  Not Graduate            No
# 25   LP001066    Male     Yes          0      Graduate           Yes
# 58   LP001198    Male     Yes          1      Graduate            No
# 88   LP001289    Male      No          0      Graduate            No
# 107  LP001370    Male      No          0  Not Graduate           NaN
# 113  LP001392  Female      No          1      Graduate           Yes
# 148  LP001519  Female      No          0      Graduate            No
# 152  LP001531    Male      No          0      Graduate            No
# 157  LP001543    Male     Yes          1      Graduate            No
# 161  LP001562    Male     Yes          0      Graduate            No
# 164  LP001572    Male     Yes          0      Graduate            No
# 169  LP001580    Male     Yes          2      Graduate            No
# 189  LP001647    Male     Yes          0      Graduate            No
# ...

# %%
loan_df.select_dtypes(include='object').columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
c1=loan_df['Married']=='Yes'
c2=loan_df['Education']=='Graduate'
c3=loan_df['Education']=='Not Graduate'
con1=c1&c2
con2=c1&c3
print(f"The number of gradated stdents who are married are {len(loan_df[con1])}")
print(f"The number of gradated stdents who are married are {len(loan_df[con2])}")
# Out:
# The number of gradated stdents who are married are 309
# The number of gradated stdents who are married are 89

# %%
labels=loan_df['Married'].unique()
for i in labels:
    c1=
# Out:
#   Cell In[9], line 3
#     c1=
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Session-7

# %%
path=r"C:\Users\saiki\data science\datasets\Hackathon\train_ctrUa4K.csv"
loan_df=pd.read_csv(path)
cat_cols=loan_df.select_dtypes(include='object').columns
for i in cat_cols[1:]:
    from sklearn.preprocessing import LabelEncoder
    le=LabelEncoder()
    loan_df[i]=le.fit_transform(loan_df[i])
loan_df
# Out:
#       Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0    LP001002       1        0           0          0              0
# 1    LP001003       1        1           1          0              0
# 2    LP001005       1        1           0          0              1
# 3    LP001006       1        1           0          1              0
# 4    LP001008       1        0           0          0              0
# ..        ...     ...      ...         ...        ...            ...
# 609  LP002978       0        0           0          0              0
# 610  LP002979       1        1           3          0              0
# 611  LP002983       1        1           1          0              0
# 612  LP002984       1        1           2          0              0
# 613  LP002990       0        0           0          0              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
le.inverse_transform(loan_df['Education'][:5])
# Out:
# array(['N', 'N', 'N', 'Y', 'N'], dtype=object)

# %%
Edu=loan_df['Education']=='Graduate'
loan_df['Education']=np.where(Edu,0,1)
loan_df
# Out:
#       Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0    LP001002       1        0           0          1              0
# 1    LP001003       1        1           1          1              0
# 2    LP001005       1        1           0          1              1
# 3    LP001006       1        1           0          1              0
# 4    LP001008       1        0           0          1              0
# ..        ...     ...      ...         ...        ...            ...
# 609  LP002978       0        0           0          1              0
# 610  LP002979       1        1           3          1              0
# 611  LP002983       1        1           1          1              0
# 612  LP002984       1        1           2          1              0
# 613  LP002990       0        0           0          1              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
pd.get_dummies(loan_df,columns=['Education'])
# Out:
#       Loan_ID  Gender  Married  Dependents  Self_Employed  ApplicantIncome  \
# 0    LP001002       1        0           0              0             5849
# 1    LP001003       1        1           1              0             4583
# 2    LP001005       1        1           0              1             3000
# 3    LP001006       1        1           0              0             2583
# 4    LP001008       1        0           0              0             6000
# ..        ...     ...      ...         ...            ...              ...
# 609  LP002978       0        0           0              0             2900
# 610  LP002979       1        1           3              0             4106
# 611  LP002983       1        1           1              0             8072
# 612  LP002984       1        1           2              0             7583
# 613  LP002990       0        0           0              1             4583
#
# ...

# %%
papp=loan_df['ApplicantIncome']
papp_mean=loan_df['ApplicantIncome'].mean()
papp_std=loan_df['ApplicantIncome'].std()
Nr=papp-papp_mean
ApplicantIncome_z=loan_df['ApplicantIncome_z']=Nr/papp_std

# %%
loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_df['ApplicantIncome'].max(),loan_df['ApplicantIncome_z'].max()
# Out:
# (81000, 12.374533479765521)

# %%
loan_df['ApplicantIncome'].idxmin()
# Out:
# 216

# %%
loan_df['ApplicantIncome'].idxmax()
# Out:
# 409

# %%
cols=['ApplicantIncome','ApplicantIncome_z']
ids=[409,216]
loan_df[['ApplicantIncome','ApplicantIncome_z']].iloc[[409,216]]
loan_df[cols].iloc[ids]
# Out:
#      ApplicantIncome  ApplicantIncome_z
# 409            81000          12.374533
# 216              150          -0.859948

# %%
keys=loan_df['Education'].value_counts().keys()
values=loan_df['Education'].value_counts().values
values
# Out:
# array([480, 134], dtype=int64)

# %%
plt.pie(values,labels=keys,autopct="%0.2f%%")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
